# %%
from model import TFPDF
from auxiliary import extractor

import pandas as pd
import re
from bs4 import BeautifulSoup
from datetime import datetime

# %%
news = pd.read_csv('news.csv')

# %%
news
# Out:
#       press_code press_name  \
# 0             14     파이낸셜뉴스
# 1              1       연합뉴스
# 2              1       연합뉴스
# 3              1       연합뉴스
# 4             18       이데일리
# ...          ...        ...
# 1881          20       동아일보
# 1882          20       동아일보
# 1883          20       동아일보
# 1884          20       동아일보
# 1885          20       동아일보
#
#                                                   title  \
# 0     <h3 id="articleTitle">&lt;부고&gt; 서남종씨(KB부동산신탁 ...
# 1     <h3 id="articleTitle">''몰래영업'' 유흥주점 급습한 이재명 경기...
# 2     <h3 id="articleTitle">''몰래영업'' 유흥주점 급습한 이재명 경기...
# 3     <h3 id="articleTitle">''강원 62명'' 코로나 사태 이후 하루 ...
# 4     <h4 class="title">올림픽 4인방 김효주만 언더파..박인비·김세영 이븐...
# ...                                                 ...
# 1881  <h3 id="articleTitle">[단독]文 만난 셔먼 “中과 대북정책 심도있...
# 1882  <h3 id="articleTitle">靑, ‘댓글조작’ 이틀째 침묵… 野 “선거조...
# 1883  <h3 id="articleTitle">“민노총 집회 막아주세요” 엄마들이 나섰다<...
# 1884     <h3 id="articleTitle">불교 사회참여 이끈 월주 스님 입적</h3>
# 1885  <h3 id="articleTitle">김경수, 대선전후 13개월간 32차례…  드...
#
#                                                contents  \
# 0     <div class="_article_body_contents" id="articl...
# 1     <div class="_article_body_contents" id="articl...
# 2     <div class="_article_body_contents" id="articl...
# 3     <div class="_article_body_contents" id="articl...
# 4     <div class="news_end" id="newsEndContents">\n<...
# ...                                                 ...
# 1881  <div class="_article_body_contents" id="articl...
# 1882  <div class="_article_body_contents" id="articl...
# 1883  <div class="_article_body_contents" id="articl...
# 1884  <div class="_article_body_contents" id="articl...
# 1885  <div class="_article_body_contents" id="articl...
#
#                                                     url  \
# 0     https://news.naver.com/main/read.naver?mode=LP...
# 1     https://news.naver.com/main/read.naver?mode=LP...
# 2     https://news.naver.com/main/read.naver?mode=LP...
# 3     https://news.naver.com/main/read.naver?mode=LP...
# 4     https://news.naver.com/main/read.naver?mode=LP...
# ...                                                 ...
# 1881  https://news.naver.com/main/read.naver?mode=LP...
# 1882  https://news.naver.com/main/read.naver?mode=LP...
# 1883  https://news.naver.com/main/read.naver?mode=LP...
# 1884  https://news.naver.com/main/read.naver?mode=LP...
# 1885  https://news.naver.com/main/read.naver?mode=LP...
#
#                     date_upload                date_modify
# 0           2021.07.23. 오전 8:03                    \n좋아요\n
# 1           2021.07.23. 오전 8:02                        NaN
# 2           2021.07.23. 오전 8:02                        NaN
# 3           2021.07.23. 오전 8:04                        NaN
# 4     기사입력 2021.07.23. 오전 08:07  최종수정 2021.07.23. 오전 08:07
# ...                         ...                        ...
# 1881        2021.07.23. 오전 3:02        2021.07.23. 오전 3:02
# 1882        2021.07.23. 오전 3:02        2021.07.23. 오전 3:02
# 1883        2021.07.23. 오전 3:02        2021.07.23. 오전 3:02
# 1884        2021.07.23. 오전 3:02        2021.07.23. 오전 3:02
# 1885        2021.07.23. 오전 3:02        2021.07.23. 오전 3:02
#
# [1886 rows x 7 columns]

# %%
tfpdf = TFPDF(news)
# Out:
#   0%|                                                                                 | 2/4128 [00:00<03:54, 17.58it/s]
# calculate words weight
# 100%|██████████████████████████████████████████████████████████████████████████████| 4128/4128 [04:06<00:00, 16.74it/s]

# %%
filtered_news_dataframe = tfpdf._get_filtered_news_dataframe()

# %%
filtered_news_dataframe
# Out:
#     press_code press_name                                              title  \
# 0          366       조선비즈  <h3 id="articleTitle">“한국계 대표가 이끄는 美 칼라일그룹, 사모...
# 1           23       조선일보  <h3 id="articleTitle">[도쿄 24시] 선수촌서 하루 최다 4명 확...
# 2            9       매일경제  <h3 id="articleTitle">[속보] 수도권 거리두기 4단계·오후 6시 ...
# 3           16      헤럴드경제  <h3 id="articleTitle">[속보]“수도권 거리두기 4단계·18시이후 ...
# 4            8      머니투데이  <h3 id="articleTitle">[속보]수도권 사회적 거리두기 4단계 2주간...
# ..         ...        ...                                                ...
# 86          18       이데일리  <h3 id="articleTitle">[속보]코로나19 백신 신규 접종자 14만명...
# 87          18       이데일리  <h3 id="articleTitle">퓨쳐켐, 진단용 방사성의약품 제조를 위한 신...
# 88          28        한겨레  <h3 id="articleTitle">[속보] 코로나19 신규 확진자 1630명…...
# 89          18       이데일리  <h3 id="articleTitle">[속보]비수도권 확진자 비중 36%…6일 연...
# 90         469       한국일보  <h3 id="articleTitle">[속보] 코로나 신규 확진자 1630명......
#
#                                              contents  \
# 0   <div class="_article_body_contents" id="articl...
# 1   <div class="_article_body_contents" id="articl...
# 2   <div class="_article_body_contents" id="articl...
# 3   <div class="_article_body_contents" id="articl...
# 4   <div class="_article_body_contents" id="articl...
# ..                                                ...
# 86  <div class="_article_body_contents" id="articl...
# 87  <div class="_article_body_contents" id="articl...
# 88  <div class="_article_body_contents" id="articl...
# 89  <div class="_article_body_contents" id="articl...
# 90  <div class="_article_body_contents" id="articl...
#
#                                                   url          date_upload  \
# 0   https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 8:14
# 1   https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 3:08
# 2   https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 8:32
# 3   https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 8:32
# 4   https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 8:31
# ..                                                ...                  ...
# 86  https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 9:32
# 87  https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 9:34
# 88  https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 9:38
# 89  https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 9:40
# 90  https://news.naver.com/main/read.naver?mode=LP...  2021.07.23. 오전 9:39
#
#             date_modify                      title_tokenized  \
# 0                   NaN  한국 대표 칼라일 그룹 사모펀드 사상 최대 규모 펀드 조성 추진
# 1   2021.07.23. 오전 3:08  도쿄 시 선수촌 하루 최다 명 확진 티켓 만 장 중 만 장 환불
# 2                   NaN       속보 수도 거리 단계 오후 시 이후 모임 금지 주 연장
# 3                   NaN  속보 수도 거리 단계 시 이후 인 이상 사적 모임 금지 주 연장
# 4                   NaN                속보 수도 사회 거리 단계 주 간 연장
# ..                  ...                                  ...
# 86                  NaN                 속보 코 백신 신규 접종 만 명 국민
# 87                  NaN         퓨쳐켐 진단 방사 의약품 제조 신규 표지 기술 개발
# 88                  NaN               속보 코로나 신규 확진 명 일 천 명 대
# 89                  NaN                     속보 수도 확진 비중 일 연속
# 90                  NaN                  속보 코로나 신규 확진 명 수도 명
#
#                  unit_vector             vector
# 0               [최대, 대표, 한국]           최대 대표 한국
# 1               [도쿄, 확진, 하루]           도쿄 확진 하루
# 2       [단계, 속보, 연장, 수도, 거리]     단계 속보 연장 수도 거리
# 3       [단계, 속보, 연장, 수도, 거리]     단계 속보 연장 수도 거리
# 4   [단계, 사회, 속보, 연장, 수도, 거리]  단계 속보 사회 연장 수도 거리
# ..                       ...                ...
# 86              [신규, 속보, 국민]           신규 속보 국민
# 87              [신규, 기술, 개발]           신규 기술 개발
# 88         [신규, 확진, 속보, 코로나]       신규 확진 속보 코로나
# 89          [연속, 확진, 속보, 수도]        연속 확진 속보 수도
# 90     [확진, 속보, 코로나, 신규, 수도]    확진 속보 코로나 신규 수도
#
# [91 rows x 10 columns]

# %%
filtered_news_dataframe.title = filtered_news_dataframe.title.apply(lambda x: BeautifulSoup(x, 'lxml').text)
filtered_news_dataframe.title = filtered_news_dataframe.title.apply(lambda x: re.sub('[\n|\t]', '', x))

filtered_news_dataframe['date'] = filtered_news_dataframe.date_upload.apply(lambda x: extractor.getDate(x))
filtered_news_dataframe.date = pd.to_datetime(filtered_news_dataframe.date, format = '%Y-%m-%d')
filtered_news_dataframe['time'] = filtered_news_dataframe.date

union_set_lists = tfpdf.get_cluster()

main_list = []
for union_set in union_set_lists[:10]:
    temp_dataframe = filtered_news_dataframe.iloc[union_set]
    sub_main_news = temp_dataframe.iloc[0]
    contents = BeautifulSoup(sub_main_news.contents, 'lxml')
    similar = [{'title': row.title, 'url':row.url, 'press_name': row.press_name, 'date': row.date} for row in temp_dataframe.iloc[1:].itertuples()]
    main_dictionary = {
        'date': sub_main_news.date,
        'keyword': tfpdf.get_keyword(union_set),
        'title': sub_main_news.title,
        'press_name': sub_main_news.press_name,
        'url': sub_main_news.url,
        'similar': similar
        }

    main_list.append(main_dictionary)

# %%
main_list[0]
# Out:
# {'date': Timestamp('2021-07-23 00:00:00'),
#  'keyword': ['단계', '연장', '수도'],
#  'title': '[속보] 수도권 거리두기 4단계·오후 6시 이후 3인모임 금지 2주 연장',
#  'press_name': '매일경제',
#  'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=009&aid=0004828248',
#  'similar': [{'title': '[속보]“수도권 거리두기 4단계·18시이후 3인이상 사적모임 금지 2주 연장”',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=016&aid=0001865321',
#    'press_name': '헤럴드경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]수도권 사회적 거리두기 4단계 2주간 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=008&aid=0004620761',
#    'press_name': '머니투데이',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '4차 유행 일평균 확진자 1400명…수도권 거리두기 4단계 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=018&aid=0004992557',
#    'press_name': '이데일리',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "''수도권 거리두기 4단계'' 2주 연장…18시 이후 3인이상 사적모임 금지",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=008&aid=0004620764',
#    'press_name': '머니투데이',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]수도권 4단계 2주 연장…저녁 3인 모임 금지 유지',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=020&aid=0003372008',
#    'press_name': '동아일보',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 4단계 2주 연장할듯… 지방은 전부 3단계 검토',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=023&aid=0003628885',
#    'press_name': '조선일보',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '오늘 1천600명대 초중반…수도권 4단계 2주연장 가닥, 오전 발표',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012544396',
#    'press_name': '연합뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 거리두기 4단계·오후 6시 이후 3인모임 금지 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012544513',
#    'press_name': '연합뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "수도권 ''거리두기 4단계'' 2주 연장…저녁 ''3인 모임'' 금지 계속 [종합]",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=015&aid=0004582351',
#    'press_name': '한국경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보] “수도권 사회적 거리두기 4단계 2주 연장”',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=081&aid=0003203778',
#    'press_name': '서울신문',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "[속보] 수도권 거리두기 4단계 2주 연장…저녁 ''3인 금지'' 유지",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=015&aid=0004582326',
#    'press_name': '한국경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 4단계 2주 연장, 3인 이상 사적 모임 금지',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012544548',
#    'press_name': '연합뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 사회적 거리두기 4단계 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012544536',
#    'press_name': '연합뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "4단계도 안 먹혔다…오늘 ''거리두기 연장 여부'' 발표",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=008&aid=0004620721',
#    'press_name': '머니투데이',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]코로나 신규 확진자 1630명, 수도권 거리두기 4단계 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=014&aid=0004680069',
#    'press_name': '파이낸셜뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 4단계 2주 연장…오후 6시 이후 ‘3인 모임 금지’ 계속',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=023&aid=0003628911',
#    'press_name': '조선일보',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 거리두기 4단계·18시이후 3인이상 사적모임 금지 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=016&aid=0001865352',
#    'press_name': '헤럴드경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]수도권 거리두기 4단계·오후 6시 이후 3인모임 금지 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=025&aid=0003120867',
#    'press_name': '중앙일보',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '중대본, 수도권 거리두기 4단계 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012544563',
#    'press_name': '연합뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '오늘 확진자 1600명대 전망…수도권 4단계 2주 연장될 듯[모닝브리핑]',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=015&aid=0004582297',
#    'press_name': '한국경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "오늘도 1,000명대 후반 확진 육박할 듯···수도권 4단계 2주연장 ''유력''",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=011&aid=0003940608',
#    'press_name': '서울경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '“수도권 사회적 거리두기 4단계 2주 연장”',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=081&aid=0003203781',
#    'press_name': '서울신문',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]코로나19 신규 확진 1630명···수도권 거리두기 4단계 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=032&aid=0003087367',
#    'press_name': '경향신문',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '거리두기 4단계 연장에..신음하는 식당가 "어찌하오리까"',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=018&aid=0004992596',
#    'press_name': '이데일리',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 ‘4단계+α’ 연장 유력, 비수도권 ‘일괄 3단계’ 검토',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=025&aid=0003120751',
#    'press_name': '중앙일보',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "[밑줄 쫙!] 연이은 확산세...수도권은 4단계 연장, 비수도권도 ''일괄 3단계''?",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=018&aid=0004992426',
#    'press_name': '이데일리',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '정부, 오늘 수도권 거리두기 조정안 발표…4단계 연장할듯',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=018&aid=0004992438',
#    'press_name': '이데일리',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '신규 확진 1842명 또 최다… 수도권 4단계 2주간 더 연장될 듯',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=081&aid=0003203690',
#    'press_name': '서울신문',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "''4단계+α'' 오늘 더 강력한 거리두기 방안 나올까",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=014&aid=0004679987',
#    'press_name': '파이낸셜뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]수도권 사회적 거리두기 4단계 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=018&aid=0004992551',
#    'press_name': '이데일리',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보] 수도권 사회적거리두기 4단계 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=028&aid=0002553779',
#    'press_name': '한겨레',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]수도권 거리두기 4단계 다음달 8일까지 2주 연장',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=032&aid=0003087358',
#    'press_name': '경향신문',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': "''수도권 4단계·18시이후 3인이상 금지'' 2주 연장",
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=014&aid=0004680039',
#    'press_name': '파이낸셜뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '수도권 4단계·오후 6시 이후 3인모임 금지 내달 8일까지 2주 연장(종합)',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012544560',
#    'press_name': '연합뉴스',
#    'date': Timestamp('2021-07-23 00:00:00')}]}

# %%
main_list[1]
# Out:
# {'date': Timestamp('2021-07-23 00:00:00'),
#  'keyword': ['확진', '속보', '신규'],
#  'title': '[속보] 중대본 "오늘 신규 확진자 수 1천600명대 초반 예상"',
#  'press_name': '연합뉴스',
#  'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012544517',
#  'similar': [{'title': '[속보] 코로나19 어제 확진자 1,630명···17일째 1,000명대',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=011&aid=0003940671',
#    'press_name': '서울경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보] 신규 확진 1630명…17일째 1000명대',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=023&aid=0003628915',
#    'press_name': '조선일보',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보]코로나19 신규 확진자 1630명…사흘 만에 1700명 아래로',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=018&aid=0004992634',
#    'press_name': '이데일리',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보] 코로나19 신규 확진자 1630명…17일째 1천명대',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=028&aid=0002553803',
#    'press_name': '한겨레',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '[속보] 코로나 신규 확진자 1630명...수도권만 1009명',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=469&aid=0000619239',
#    'press_name': '한국일보',
#    'date': Timestamp('2021-07-23 00:00:00')}]}

# %%
main_list[2]
# Out:
# {'date': Timestamp('2021-07-23 00:00:00'),
#  'keyword': ['도시', '공모', '개발'],
#  'title': "''영종하늘도시2차 주택개발리츠'' 일반인 대상 공모진행",
#  'press_name': '매일경제',
#  'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=009&aid=0004828255',
#  'similar': [{'title': '‘영종하늘도시2차 주택개발리츠’, 23일 일반인 대상 우선주 공모 마감',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=032&aid=0003087363',
#    'press_name': '경향신문',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '‘영종하늘도시2차 주택개발리츠’, 일반인 대상 우선주 공모 마감',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=015&aid=0004582333',
#    'press_name': '한국경제',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '‘영종하늘도시2차 주택개발리츠’ 일반인 우선주 공모 23일 마감',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=366&aid=0000748892',
#    'press_name': '조선비즈',
#    'date': Timestamp('2021-07-23 00:00:00')},
#   {'title': '‘영종하늘도시2차 주택개발리츠’ 일반인 우선주 공모 오늘(23일) 마감',
#    'url': 'https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=011&aid=0003940636',
#    'press_name': '서울경제',
#    'date': Timestamp('2021-07-23 00:00:00')}]}
